# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
import matplotlib.pyplot as plt

# %%
mnist = tf.keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train / 255.0
X_test = X_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
baseline_model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

baseline_model.compile(optimizer='adam',
                       loss='sparse_categorical_crossentropy',
                       metrics=['accuracy'])

history_baseline = baseline_model.fit(
    X_train, y_train,
    epochs=10,
    validation_split=0.2,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9230 - loss: 0.2653 - val_accuracy: 0.9564 - val_loss: 0.1431
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9675 - loss: 0.1074 - val_accuracy: 0.9660 - val_loss: 0.1081
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9775 - loss: 0.0736 - val_accuracy: 0.9730 - val_loss: 0.0886
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9833 - loss: 0.0537 - val_accuracy: 0.9712 - val_loss: 0.0983
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9862 - loss: 0.0439 - val_accuracy: 0.9701 - val_loss: 0.1112
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9880 - loss: 0.0354 - val_accuracy: 0.9716 - val_loss: 0.1048
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9898 - loss: 0.0289 - val_accuracy: 0.9697 - val_loss: 0.1068
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9918 - loss: 0.0241 - val_accuracy: 0.9678 - val_loss: 0.1233
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9933 - loss: 0.0192 - val_accuracy: 0.9742 - val_loss: 0.1047
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9936 - loss: 0.0192 - val_accuracy: 0.9747 - val_loss: 0.1095

# %%
baseline_model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

baseline_model.compile(optimizer='adam',
                       loss='sparse_categorical_crossentropy',
                       metrics=['accuracy'])

history_baseline = baseline_model.fit(
    X_train, y_train,
    epochs=10,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9219 - loss: 0.2669 - val_accuracy: 0.9591 - val_loss: 0.1391
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9665 - loss: 0.1089 - val_accuracy: 0.9640 - val_loss: 0.1202
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9770 - loss: 0.0747 - val_accuracy: 0.9710 - val_loss: 0.0973
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9824 - loss: 0.0557 - val_accuracy: 0.9697 - val_loss: 0.1096
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9849 - loss: 0.0466 - val_accuracy: 0.9704 - val_loss: 0.1038
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9884 - loss: 0.0350 - val_accuracy: 0.9733 - val_loss: 0.1017
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9901 - loss: 0.0290 - val_accuracy: 0.9734 - val_loss: 0.1071
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9920 - loss: 0.0236 - val_accuracy: 0.9697 - val_loss: 0.1277
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9930 - loss: 0.0206 - val_accuracy: 0.9729 - val_loss: 0.1263
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9942 - loss: 0.0175 - val_accuracy: 0.9749 - val_loss: 0.1108

# %%
l2_model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(64, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(10, activation='softmax')
])

l2_model.compile(optimizer='adam',
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])

history_l2 = l2_model.fit(
    X_train, y_train,
    epochs=10,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9184 - loss: 0.4561 - val_accuracy: 0.9542 - val_loss: 0.3023
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9576 - loss: 0.2785 - val_accuracy: 0.9628 - val_loss: 0.2490
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9640 - loss: 0.2386 - val_accuracy: 0.9624 - val_loss: 0.2393
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9686 - loss: 0.2158 - val_accuracy: 0.9680 - val_loss: 0.2115
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9703 - loss: 0.2017 - val_accuracy: 0.9637 - val_loss: 0.2222
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9721 - loss: 0.1901 - val_accuracy: 0.9671 - val_loss: 0.2010
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9727 - loss: 0.1850 - val_accuracy: 0.9719 - val_loss: 0.1872
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9748 - loss: 0.1743 - val_accuracy: 0.9718 - val_loss: 0.1800
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9744 - loss: 0.1688 - val_accuracy: 0.9724 - val_loss: 0.1772
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9761 - loss: 0.1643 - val_accuracy: 0.9718 - val_loss: 0.1834

# %%
dropout_model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3), # Dropout layer
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.3), # Dropout layer
    layers.Dense(10, activation='softmax')
])

dropout_model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

history_dropout = dropout_model.fit(
    X_train, y_train,
    epochs=10,
    validation_split=0.2,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8681 - loss: 0.4318 - val_accuracy: 0.9513 - val_loss: 0.1580
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9361 - loss: 0.2172 - val_accuracy: 0.9588 - val_loss: 0.1335
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9502 - loss: 0.1706 - val_accuracy: 0.9689 - val_loss: 0.1085
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9567 - loss: 0.1464 - val_accuracy: 0.9718 - val_loss: 0.0976
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9609 - loss: 0.1297 - val_accuracy: 0.9735 - val_loss: 0.0929
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9649 - loss: 0.1185 - val_accuracy: 0.9729 - val_loss: 0.0953
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9672 - loss: 0.1086 - val_accuracy: 0.9736 - val_loss: 0.0950
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9682 - loss: 0.1033 - val_accuracy: 0.9752 - val_loss: 0.0868
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9699 - loss: 0.0982 - val_accuracy: 0.9760 - val_loss: 0.0895
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9710 - loss: 0.0930 - val_accuracy: 0.9763 - val_loss: 0.0896

# %%
batchnorm_model = models.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dense(64),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dense(10, activation='softmax')
])

batchnorm_model.compile(optimizer='adam',
                        loss='sparse_categorical_crossentropy',
                        metrics=['accuracy'])

history_batchnorm = batchnorm_model.fit(
    X_train, y_train,
    epochs=10,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9241 - loss: 0.2687 - val_accuracy: 0.9617 - val_loss: 0.1240
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9634 - loss: 0.1179 - val_accuracy: 0.9726 - val_loss: 0.0915
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9715 - loss: 0.0897 - val_accuracy: 0.9742 - val_loss: 0.0870
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9770 - loss: 0.0715 - val_accuracy: 0.9761 - val_loss: 0.0784
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9810 - loss: 0.0604 - val_accuracy: 0.9760 - val_loss: 0.0831
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9839 - loss: 0.0509 - val_accuracy: 0.9763 - val_loss: 0.0852
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9837 - loss: 0.0490 - val_accuracy: 0.9747 - val_loss: 0.0891
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9864 - loss: 0.0415 - val_accuracy: 0.9776 - val_loss: 0.0782
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9881 - loss: 0.0355 - val_accuracy: 0.9768 - val_loss: 0.0838
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9886 - loss: 0.0339 - val_accuracy: 0.9779 - val_loss: 0.0824

# %%
plt.plot(history_baseline.history['val_loss'], label='Baseline')
plt.plot(history_dropout.history['val_loss'], label='Dropout')
plt.plot(history_l2.history['val_loss'], label='L2')
plt.plot(history_batchnorm.history['val_loss'], label='BatchNorm')

plt.xlabel("Epochs")
plt.ylabel("Validation Loss")
plt.legend()
plt.title("Validation Loss Comparison")
plt.show()

# %%
plt.plot(history_baseline.history['val_accuracy'], label='Baseline')
plt.plot(history_dropout.history['val_accuracy'], label='Dropout')
plt.plot(history_l2.history['val_accuracy'], label='L2')
plt.plot(history_batchnorm.history['val_accuracy'], label='BatchNorm')

plt.xlabel("Epochs")
plt.ylabel("Validation Accuracy")
plt.legend()
plt.title("Validation Accuracy Comparison")
plt.show()
